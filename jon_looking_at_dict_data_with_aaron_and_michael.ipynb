# %%
#built in modules
from pathlib import Path
import json 

#installed modules
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 

#internal imports
from utilities.qualisys_to_generic_skeleton_converter import qualisys_to_generic_skeleton_converter

# %%
# load the json as a dictionary

path_to_data_json = Path(r"C:\Users\WindowsPC_Hallway\Downloads\demo_data_argp_analysis_Oct2022\qualisys_dict.json")

qualisys_json_to_load = open(str(path_to_data_json))
qualisys_dict = json.load(qualisys_json_to_load)

# %%
# process qualisys dictionary into the mediapipe-ish format

generic_skelly_dict = qualisys_to_generic_skeleton_converter(qualisys_dict)

# %%
right_foot_xyz = generic_skelly_dict["right_foot_xyz"]
right_foot_z = right_foot_xyz[:,2]

# %%
# !pip install pyqt5

# %%
# %matplotlib qt

# %%
plt.plot(right_foot_xyz[:,1])
plt.show()

# %%
right_foot_velocity = np.diff(right_foot_xyz, axis = 0)

# %%
plt.plot(right_foot_velocity[:,1])
plt.show()

# %%
right_foot_y_vel = right_foot_velocity[8374:8374+800,1]

# %%
minimum_velocity_index = np.argmin(right_foot_y_vel)
minimum_velocity_index

# %%
plt.plot(right_foot_y_vel,'b.-')
plt.plot(minimum_velocity_index, right_foot_y_vel[minimum_velocity_index],'ro')

plt.show()

# %%
velocity_threshold = 2
frames_where_the_velocity_is_below_threshold = right_foot_y_vel<velocity_threshold
# frames_where_the_velocity_is_below_threshold
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
plt.plot(right_foot_y_vel,'b.-')
plt.plot(right_foot_y_vel[frames_where_the_velocity_is_below_threshold],'ro')

plt.show()
